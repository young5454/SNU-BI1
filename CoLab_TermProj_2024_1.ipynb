# %% [markdown]
# # 생물정보학 및 실습 1 - Term Project용 환경 셋업
#
# ```
# 생물정보학 및 실습 1
# 서울대학교 생물정보학전공/생명과학부 2024년 1학기
#
# 이 노트북은 Creative Commons BY-SA 조건으로 재사용 가능합니다.
# 장혜식 <hyeshik@snu.ac.kr>, 서울대학교 생명과학부
# ```
#
# 이 노트북은 Google Colab을 이용해서 Term Project를 할 수 있도록 환경을 준비해 줍니다. 터미널 사용이 원활하지 않은 상태이고, 데이터를 오랫동안 보관하기 어렵기 때문에 되도록 개인용 컴퓨터에서 [Anaconda](https://www.anaconda.com/)나 [JupyterLab](https://jupyterlab.readthedocs.io/en/stable/) 등을 설치하고 사용하시는 것이 편하지만, 개인용 컴퓨터 사양이 부족한 경우에는 Google CoLab을 사용할 수도 있습니다. 개인용 컴퓨터를 쓸 때는 Windows에서는 [WSL2](https://docs.microsoft.com/en-us/windows/wsl/install-win10)를 쓰시면 리눅스 커맨드라인 환경을 쓸 수 있습니다. Google Colab은 창을 닫은 후 90분 후, 또는 창을 처음 열고 12시간 후에 환경을 닫아버리기 때문에 매번 실습할 때마다 새로 셋업이 필요합니다. `Runtime->Run All`을 실행해서 전체를 한 번 실행하시면 준비됩니다. 모든 것이 잘 안 되고 뭔가 꼬인 느낌이 강하게 들 때는 `Runtime->Factory reset runtime`을 누르고 새로 시작하시면 될 수도 있습니다.

# %% [markdown]
# ## Google Drive 마운트
#
# 데이터 파일들을 불러오고 저장하기 위해서 Google Drive를 연결합니다. **이번엔 스크립트 파일을 편집해야 하기 때문에 Google Drive 마운트를 하지 않으면 vim등 콘솔에서 쓸 수 있는 에디터를 쓰셔야 합니다.** 화면에 나오는 주소를 눌러서 인증하고 인증 코드를 그 아래에 입력하세요. 그러면 `/contents/drive/MyDrive`에서 자신의 Drive 최상단 폴더가 보입니다. Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 저장공간이 충분하므로 이 부분은 생략하고 지나갑니다.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 실습용 Bioconda 환경 설치하기
# Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 따로 실습용 [Bioconda](https://bioconda.github.io/) 환경을 구축해서 이 노트북을 그 환경 안에서 띄우시면 됩니다.
#
# CoLab을 쓰시는 분들은 다음에 따라서 실습용 프로그램들을 쉽게 설치할 수 있도록 [Bioconda](https://bioconda.github.io/) 환경을 만듭니다. 실행하고 진행상황을 관찰하다가 에러로 보이는 것이 있으면 잘 읽어보고 해결합니다.
#
# 파이썬 모듈들은 Colab쪽의 파이썬 인터프리터를 바꿀 수 없기 때문에 Conda에 설치하더라도 사용하기 어렵습니다. 파이썬 모듈은 `pip` 명령어로 설치하시면 Colab에서 불러와서 사용할 수 있습니다.
#
# 환경 초기화에 관련된 스크립트는 [GitHub 프로젝트](https://github.com/hyeshik/colab-biolab)에 있습니다.

# %%
# !git clone https://github.com/hyeshik/colab-biolab.git
# !cd colab-biolab && bash tools/setup.sh
exec(open('colab-biolab/tools/activate_conda.py').read())

# %% [markdown]
# Google CoLab에서 shell command를 실행할 때는 명령 앞에 !을 붙이면 실행할 수 있습니다.

# %% [markdown]
# ## 시퀀싱 데이터 다운로드
# 이제 실습 수업에서 필요한 시퀀싱 데이터를 다운로드 받아서 설치합시다. 드라이브 공간만 충분하면 데이터는 계속 저장돼 있기 때문에 학기 전체를 통해서 딱 한 번만 하시면 됩니다. Colab에서는 작업용 데이터를 Google Drive 폴더 아래의 `binfo-datapack1`에 저장합니다. 실습용 데이터는 `/content/drive/MyDrive/binfo1-datapack1`에 풀리게 됩니다.
#
# ### (Option 1) Google CoLab에서 접속한 경우
# 1. [Google Drive 공유폴더](https://drive.google.com/drive/folders/1QBJednh-C7A17PFOlpZHBKyDmBvd6klh?usp=sharing)에 접속합니다.
# 1. 중간 제목줄의 "binfo1-datapack1 ▾"에서 ▾을 누릅니다.
# 1. Add shortcut to Drive를 누릅니다.
# 1. My Drive를 선택해서 ADD SHORTCUT 버튼을 누릅니다.
# 1. 다음 cell을 실행해서 링크가 제대로 들어왔는지 확인합니다. (바로 확인되지 않으면 3–5분 정도 기다렸다가 하면 됩니다.)
# 1. 제대로 확인되면 다음으로 넘어갑니다.

# %%
# !ls -al /content/drive/MyDrive/binfo1-datapack1/

# %% [markdown]
# ### (Option 2) CoLab외의 다른 환경에서 접속한 경우
# 본인 컴퓨터나 연구실 워크스테이션 등에서 작업하는 경우에는 다음 명령어로 다운로드 받으시면 됩니다. 첫 번째에는 wget이 접속오류를 내는 경우가 많으니, 접속에러가 발생하면 다시 한 번 실행해 보세요. `/content/drive/Mydrive` 부분은 원하는 저장 경로로 바꿔서 지정하시면 됩니다.

# %%
# Check current directory
# !pwd
# Out:
# /Users/kimhoeyeong/Desktop/SNU 2024-1/SNU-BI1

# %%
# !wget -O - --no-check-certificate https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar | tar -C ./Data/ -xf -
# Out:
# --2024-05-03 23:39:54--  https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar
# Resolving hyeshik.qbio.io (hyeshik.qbio.io)... 147.47.203.129
# Connecting to hyeshik.qbio.io (hyeshik.qbio.io)|147.47.203.129|:443... connected.
# WARNING: cannot verify hyeshik.qbio.io's certificate, issued by ‘CN=R3,O=Let's Encrypt,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 6424668160 (6.0G) [application/octet-stream]
# Saving to: ‘STDOUT’
#
# -                    16%[==>                 ]   1.01G  9.00MB/s    in 1m 57s
#
# 2024-05-03 23:41:51 (8.84 MB/s) - Connection closed at byte 1080360661. Retrying.
#
# --2024-05-03 23:41:52--  (try: 2)  https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar
# Connecting to hyeshik.qbio.io (hyeshik.qbio.io)|147.47.203.129|:443... connected.
# WARNING: cannot verify hyeshik.qbio.io's certificate, issued by ‘CN=R3,O=Let's Encrypt,C=US’:
#   Unable to locally verify the issuer's authority.
# ...

# %% [markdown]
# 그리고, GENCODE Annotation 데이터도 미리 받아서 저장해 둡니다. 에러가 나면 다시 한 번 실행해 봅니다.

# %%
# !wget --no-check-certificate -O ./Data/binfo1-datapack1/gencode.gtf.gz http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Out:
# --2024-05-03 23:53:15--  http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28359457 (27M) [application/x-gzip]
# Saving to: ‘./Data/binfo1-datapack1/gencode.gtf.gz’
#
# ./Data/binfo1-datap 100%[===================>]  27.04M   197KB/s    in 4m 24s
#
# 2024-05-03 23:57:40 (105 KB/s) - ‘./Data/binfo1-datapack1/gencode.gtf.gz’ saved [28359457/28359457]

# %% [markdown]
# ### 파일 체크섬 확인
#
# 받은 데이터의 MD5 체크섬을 확인합니다. 한참 걸립니다. 각 파일들의 원래 체크섬은 다음과 같습니다. 한 번 비교해 보세요. (나중에 자동으로 비교하고 싶으시면 `md5sum -c` 옵션을 사용하면 됩니다. 여기서는 MD5를 처음 써 보는 의미에서 직접 비교해 봅시다.)
#
# ```
# 140aaf30bcb9276cc716f8699f04ddd6  CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  RPF-siLuc.bam.bai
# ```

# %%
# !md5sum ./Data/binfo1-datapack1/*
# Out:
# 140aaf30bcb9276cc716f8699f04ddd6  ./Data/binfo1-datapack1/CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  ./Data/binfo1-datapack1/CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  ./Data/binfo1-datapack1/RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  ./Data/binfo1-datapack1/RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  ./Data/binfo1-datapack1/RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  ./Data/binfo1-datapack1/RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  ./Data/binfo1-datapack1/RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  ./Data/binfo1-datapack1/RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  ./Data/binfo1-datapack1/RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  ./Data/binfo1-datapack1/RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  ./Data/binfo1-datapack1/RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  ./Data/binfo1-datapack1/RPF-siLuc.bam.bai
# ...

# %%
# !ls -al ./Data/binfo*
# Out:
# total 12603584
# drwxr-xr-x@ 15 kimhoeyeong  staff         480 May  4 00:01 .
# drwxr-xr-x@  4 kimhoeyeong  staff         128 May  4 00:17 ..
# -rw-r--r--   1 kimhoeyeong  staff  1370036258 May  6  2021 CLIP-35L33G.bam
# -rw-r--r--   1 kimhoeyeong  staff     3118336 May  6  2021 CLIP-35L33G.bam.bai
# -rw-r--r--   1 kimhoeyeong  staff  1003658801 May  6  2021 RNA-control.bam
# -rw-r--r--   1 kimhoeyeong  staff     2276104 May  6  2021 RNA-control.bam.bai
# -rw-r--r--   1 kimhoeyeong  staff  1260991122 May  6  2021 RNA-siLin28a.bam
# -rw-r--r--   1 kimhoeyeong  staff     2710744 May  6  2021 RNA-siLin28a.bam.bai
# -rw-r--r--   1 kimhoeyeong  staff   981684502 May  6  2021 RNA-siLuc.bam
# -rw-r--r--   1 kimhoeyeong  staff     2606104 May  6  2021 RNA-siLuc.bam.bai
# -rw-r--r--   1 kimhoeyeong  staff   737352902 May  6  2021 RPF-siLin28a.bam
# -rw-r--r--   1 kimhoeyeong  staff     2482768 May  6  2021 RPF-siLin28a.bam.bai
# ...

# %% [markdown]
# 실습에 필요한 프로그램들 몇 가지를 추가로 설치합니다.

# %%
# !conda install -y subread
# !conda install bioconda::subread
# Out:
# Channels:
#  - bioconda
#  - conda-forge
#  - defaults
# Platform: osx-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/snubi1
#
#   added / updated specs:
#     - bioconda::subread
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     subread-2.0.6              |       h45fc8d7_0        14.4 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:        14.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   subread            bioconda/osx-64::subread-2.0.6-h45fc8d7_0
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %% [markdown]
# ## Transcript count table 마련하기
#
# 제공된 alignment와 annotation 파일들을 이용해서 transcript별 read count를 구해봅니다. 실제 연구에서는 multi-mapping 등을 고려해야 하지만, 여기서는 단순화해서 모두 무시합니다.

# %% [markdown]
# 먼저 작업 디렉토리를 만들고 데이터를 원본 디렉토리에서 복사해 옵니다. (이미 이 노트북을 실행한 적이 있으면 다시 할 필요는 없습니다.)

# %%
# !mkdir ./Data/binfo1-work
# !rsync -Pav ./Data/binfo1-datapack1/ ./Data/binfo1-work/
# Out:
# building file list ...
# 14 files to consider
# ./
# CLIP-35L33G.bam
#   1370036258 100%  167.74MB/s    0:00:07 (xfer#1, to-check=12/14)
# CLIP-35L33G.bam.bai
#      3118336 100%    3.67MB/s    0:00:00 (xfer#2, to-check=11/14)
# RNA-control.bam
#   1003658801 100%  142.54MB/s    0:00:06 (xfer#3, to-check=10/14)
# RNA-control.bam.bai
#      2276104 100%    2.96MB/s    0:00:00 (xfer#4, to-check=9/14)
# RNA-siLin28a.bam
#   1260991122 100%  143.49MB/s    0:00:08 (xfer#5, to-check=8/14)
# RNA-siLin28a.bam.bai
#      2710744 100%    6.41MB/s    0:00:00 (xfer#6, to-check=7/14)
# RNA-siLuc.bam
#    981684502 100%  140.93MB/s    0:00:06 (xfer#7, to-check=6/14)
# RNA-siLuc.bam.bai
#      2606104 100%    3.74MB/s    0:00:00 (xfer#8, to-check=5/14)
# RPF-siLin28a.bam
#    737352902 100%  142.52MB/s    0:00:04 (xfer#9, to-check=4/14)
# RPF-siLin28a.bam.bai
#      2482768 100%    2.48MB/s    0:00:00 (xfer#10, to-check=3/14)
# RPF-siLuc.bam
# ...

# %%
# %cd ./Data/binfo1-work
# Out:
# /Users/kimhoeyeong/Desktop/SNU 2024-1/SNU-BI1/Data/binfo1-work
# /opt/anaconda3/envs/snubi1/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# 자! bam 파일에 담긴 aligned reads와 gtf 파일에 담긴 gene annotation으로 gene별 read count를 구합니다.

# %%
# !featureCounts -a gencode.gtf -o read-counts.txt *.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.6
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 6 BAM files                                      ||
# ||                                                                            ||
# ||                           CLIP-35L33G.bam                                  ||
# ||                           RNA-control.bam                                  ||
# ...

# %% [markdown]
# 결과를 pandas로 읽어와 봅니다.

# %%
import pandas as pd
cnts = pd.read_csv('read-counts.txt', sep='\t')
cnts.head()
# Out:
#                  Geneid                                 Chr  \
# 0  ENSMUSG00000102693.2                                chr1
# 1  ENSMUSG00000064842.3                                chr1
# 2  ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# 3  ENSMUSG00000102851.2                                chr1
# 4  ENSMUSG00000103377.2                                chr1
#
#                                                Start  \
# 0                                            3143476
# 1                                            3172239
# 2  3276124;3276746;3283662;3283832;3284705;349192...
# 3                                            3322980
# 4                                            3435954
#
#                                                  End         Strand  Length  \
# 0                                            3144545              +    1070
# 1                                            3172348              +     110
# ...

# %% [markdown]
# 이제 한 번 대충 그림을 그려 봅니다.

# %%
cnts['clip_enrichment'] = cnts['CLIP-35L33G.bam'] / cnts['RNA-control.bam']
cnts['rden_change'] = (cnts['RPF-siLin28a.bam'] / cnts['RNA-siLin28a.bam']) / (cnts['RPF-siLuc.bam'] / cnts['RNA-siLuc.bam'])
cnts.head()
# Out:
#                  Geneid                                 Chr  \
# 0  ENSMUSG00000102693.2                                chr1
# 1  ENSMUSG00000064842.3                                chr1
# 2  ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# 3  ENSMUSG00000102851.2                                chr1
# 4  ENSMUSG00000103377.2                                chr1
#
#                                                Start  \
# 0                                            3143476
# 1                                            3172239
# 2  3276124;3276746;3283662;3283832;3284705;349192...
# 3                                            3322980
# 4                                            3435954
#
#                                                  End         Strand  Length  \
# 0                                            3144545              +    1070
# 1                                            3172348              +     110
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.scatter(np.log2(cnts['clip_enrichment']),
           np.log2(cnts['rden_change']))
# Out:
# /opt/anaconda3/envs/snubi1/lib/python3.9/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# 이 그림에는 문제가 많이 있습니다. 논문의 그림 Figure 4D처럼 한 번 만들어 봅시다~

# %%
# Filter out NaNs and infinite values

clip_enrichment = np.log2(cnts['clip_enrichment'])
rden_change = np.log2(cnts['rden_change'])

valid_indices = np.isfinite(clip_enrichment) & np.isfinite(rden_change)
clip_enrichment = clip_enrichment[valid_indices]
rden_change = rden_change[valid_indices]

# print(len(clip_enrichment), len(rden_change))

# %%
from scipy import stats

# Calculate R-squared value with log2 values (Based on supplementary info)
r, _ = stats.pearsonr(clip_enrichment, rden_change)
print(r)
# Out:
# 0.2059328289045011

# %%
# 여기에 코드를 새로 작성해서 논문의 그림과 비슷하게 만들어 봅니다.

# Set Arial as the default font
plt.rcParams['font.family'] = 'Arial'

fig, ax = plt.subplots(1, 1, figsize=(4.5, 4.5))
ax.scatter(clip_enrichment,
           rden_change,
           s=2, alpha=0.1, c='black')

# Title and axis info
plt.title("CLIP and ribosome footprinting upon $\mathit{Lin28a}$ knockdown", fontsize=14)
plt.xlabel("LIN28A CLIP enrichment ($\log_2$)", fontsize=12)
plt.ylabel("Ribosome density change \n upon $\mathit{Lin28a}$ knockdown ($\log_2$)", fontsize=12)

# Axis limit
ax.set_xlim(left = -4, right = 6)
ax.set_ylim(bottom = -3, top = 2)

# Add grid
ax.grid(True)

# Add R-value
ax.annotate(f"r = {r:.4f}", xy=(0.77, 0.05), xycoords='axes fraction', fontsize=10)

# Hide the right and top spines
ax.spines[['right', 'top']].set_visible(False)

# %% [markdown]
# ## Protein localization 반영하기
#
# 논문 그림(Figure 5B, S6A)에서는 protein localization을 반영해서 색으로 나타냈습니다. 이것을 한 번 구현해 봅시다. 각 gene product의 localization을 따로 구하려면 좀 귀찮기 때문에 미리 모아 두었습니다. UniProt에서 매핑된 데이터를 토대로 아주 명확한 것만 일부 정리한 것입니다. 이것도 마찬가지로 처음엔 에러가 나기도 하니까, 다시 실행해보면 거의 잘 됩니다~

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
mouselocal = pd.read_csv('https://hyeshik.qbio.io/binfo/mouselocalization-20210507.txt', sep='\t')
mouselocal
# Out:
#                  gene_id            Gene names               type
# 0     ENSMUSG00000000001                 Gnai3          cytoplasm
# 1     ENSMUSG00000000028  Cdc45 Cdc45l Cdc45l2            nucleus
# 2     ENSMUSG00000000049            Apoh B2gp1          cytoplasm
# 3     ENSMUSG00000000058                  Cav2          cytoplasm
# 4     ENSMUSG00000000085                 Scmh1            nucleus
# ...                  ...                   ...                ...
# 9518  ENSMUSG00000117975       Itprip Kiaa1754  integral membrane
# 9519  ENSMUSG00000118332  Fam220a Acpin1 Sipar            nucleus
# 9520  ENSMUSG00000118346              Tmem179b  integral membrane
# 9521  ENSMUSG00000118504                   NaN  integral membrane
# 9522  ENSMUSG00000118560                  Lim2  integral membrane
#
# [9523 rows x 3 columns]

# %% [markdown]
# 이제 이 localization 데이터와 위에서 만든 scatter를 결합해서 논문 그림과 비슷하게 만들어 봅시다.

# %%
# 여기에 새로 코드를 작성해서 논문 그림과 비슷하게 만들어 봅시다.

# %%
# Filter matching transcripts 

# Transcript ID to GeneID
cnts['Geneid'] = cnts['Geneid'].str.split('.').str[0]

# Merge count data with protein localization data
merged_data = pd.merge(cnts, mouselocal[['gene_id', 'type']], left_on='Geneid', right_on='gene_id', how='inner')

# Drop redundant column
merged_data.drop(columns=['gene_id'], inplace=True)
merged_data.head()
# Out:
#                Geneid                                                Chr  \
# 0  ENSMUSG00000051951                 chr1;chr1;chr1;chr1;chr1;chr1;chr1
# 1  ENSMUSG00000025902  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# 2  ENSMUSG00000025903  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# 3  ENSMUSG00000002459  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# 4  ENSMUSG00000025905  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
#
#                                                Start  \
# 0  3276124;3276746;3283662;3283832;3284705;349192...
# 1  4561154;4561473;4561613;4561936;4562680;456268...
# 2  4878011;4878046;4878053;4878119;4878121;487813...
# 3  4979799;4979799;4980625;4980697;4982537;498253...
# 4  5658689;5658716;5658716;5658780;5659164;565922...
#
#                                                  End  \
# 0  3277540;3277540;3285855;3286567;3287191;349212...
# 1  4562891;4562886;4562891;4562891;4563827;456289...
# ...

# %%
columns_to_keep = ['Geneid', 'clip_enrichment', 'rden_change', 'type']
new_merged = merged_data.loc[:, columns_to_keep].copy()
new_merged.head()
# Out:
#                Geneid  clip_enrichment  rden_change               type
# 0  ENSMUSG00000051951         4.000000          NaN  integral membrane
# 1  ENSMUSG00000025902         6.000000     0.416667            nucleus
# 2  ENSMUSG00000025903         3.562718     0.760459          cytoplasm
# 3  ENSMUSG00000002459         5.000000    12.000000            nucleus
# 4  ENSMUSG00000025905        49.000000     1.142857  integral membrane

# %%
# log2 of values
new_merged['clip_enrichment'] = np.log2(new_merged['clip_enrichment'])
new_merged['rden_change'] = np.log2(new_merged['rden_change'])

# Filter out NaNs and infinite values
new_merged.replace([np.inf, -np.inf], np.nan, inplace=True)

# Filter out rows containing NaN values
filtered_new_merged = new_merged.dropna()
filtered_new_merged
# Out:
# /opt/anaconda3/envs/snubi1/lib/python3.9/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                   Geneid  clip_enrichment  rden_change               type
# 1     ENSMUSG00000025902         2.584963    -1.263034            nucleus
# 2     ENSMUSG00000025903         1.832978    -0.395057          cytoplasm
# 3     ENSMUSG00000002459         2.321928     3.584963            nucleus
# 4     ENSMUSG00000025905         5.614710     0.192645  integral membrane
# 5     ENSMUSG00000025907         2.440573    -0.547359            nucleus
# ...                  ...              ...          ...                ...
# 9517  ENSMUSG00000064358        -3.222392    -1.167072  integral membrane
# 9519  ENSMUSG00000065947        -1.584963    -1.000000  integral membrane
# 9520  ENSMUSG00000064363        -2.527089     0.146816  integral membrane
# ...

# %%
import matplotlib.lines as mlines

# Label colors
# Define colors for each type
type_colors = {
    'nucleus': 'blue',
    'integral membrane': 'red',
    'cytoplasm': 'green',
}

# Create a scatter plot - Similar to Figure S6A      
fig, ax = plt.subplots(1, 1, figsize=(5, 6))

for type_, group in filtered_new_merged.groupby('type'):
    plt.scatter(group['clip_enrichment'], group['rden_change'], 
                label=type_, 
                color=type_colors.get(type_, 'black'),
                s=2, alpha=0.2)

# Title and axis info
plt.title("Linkage to localization", fontsize=14)
plt.xlabel("LIN28A CLIP enrichment ($\log_2$)", fontsize=12)
plt.ylabel("Ribosome density change upon $\mathit{Lin28a}$ knockdown ($\log_2$)", fontsize=12)

# Legend
blue_ = mlines.Line2D([], [], color='blue', marker='o', linestyle='None',
                          markersize=5, label='Nucleus')
green_ = mlines.Line2D([], [], color='green', marker='o', linestyle='None',
                          markersize=5, label='Cytoplasm')
red_ = mlines.Line2D([], [], color='red', marker='o', linestyle='None',
                          markersize=5, label='Integral membrane')

plt.legend(handles = [blue_, red_, green_], edgecolor='black')


# Axis limit
ax.set_xlim(left = -4, right = 6)
ax.set_ylim(bottom = -3, top = 2)

# Add grid
ax.grid(True)

# Hide the right and top spines
ax.spines[['right', 'top']].set_visible(False)
